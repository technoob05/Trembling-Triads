# %% [markdown]
# # 🔬 Experiment A: The Scale Test & Trembling Hand
#
# ## Objective
# To determine if larger models (70B+) possess **"Trembling Hand Perfection"** (robustness to noise) compared to smaller models (7B/8B).
#
# **Methodology:**
# 1.  **Control Group (Baseline):** Noise = 0%. Ideal environment.
# 2.  **Treatment Group (trembling):** Noise = 5%. Random errors introduced.
# 3.  **Comparison:** We measure the drop in cooperation rates. A "smart" model should exhibit a smaller drop (forgiveness) than a "naive" model (blind retaliation).
#
# **Models:**
# *   Small: `Mistral-7B` or `Llama3-8B`
# *   Large: `Llama3-70B` or `Qwen2.5-72B` (Requires H100)

# %%
# 1. Setup
# !git clone https://github.com/technoob05/Trembling-Triads.git
# %cd Trembling-Triads
# !pip install -r requirements.txt

# %% [markdown]
# ### 🟢 Phase 1: Control Group (0% Noise)

# %%
# Small Model Baseline
# !python triad_experiment.py --game PGG --models Mistral-7B --noise 0.0 --rounds 20 --languages en

# %%
# Large Model Baseline (Uncomment on H100)
# !python triad_experiment.py --game PGG --models Llama3-70B --noise 0.0 --rounds 20 --languages en

# %% [markdown]
# ### 🔴 Phase 2: Treatment Group (5% Noise)

# %%
# Small Model with Noise
# !python triad_experiment.py --game PGG --models Mistral-7B --noise 0.05 --rounds 20 --languages en

# %%
# Large Model with Noise (Uncomment on H100)
# !python triad_experiment.py --game PGG --models Llama3-70B --noise 0.05 --rounds 20 --languages en
