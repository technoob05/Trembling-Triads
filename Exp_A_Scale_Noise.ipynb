# %% [markdown]
# # 🧪 Exp A: The Scale Test (Pillar 1: 3-IPD)
#
# ## 🎯 Objective (Research Pillar 1)
# Investigate **"Trembling Hand Perfection"** using the **3-Player Prisoner's Dilemma (3-IPD)** across a wide spectrum of model sizes.
# We test the **Coalition Stability Score (CSS)**: If we inject noise into a stable coalition, does it collapse?
#
# **Hypothesis:**
# *   **Small Models (7B)**: Fragile. One accidental defection triggers endless retaliation (DDD).
# *   **Medium Models (14B/32B)**: Transitional region. May show emerging forgiveness.
# *   **Large Models (120B)**: Robust. Can forgive accidental errors to restore the coalition.
#
# **Protocol:**
# *   **Game:** 3-Player Adjusted PD (Strict Payoff: 7/1/9/5).
# *   **Languages:** English (en), Vietnamese (vn).
# *   **Noise Levels:** $\epsilon \in \{0\%, 5\%, 10\%\}$.
# *   **Models:** Qwen2.5-32B (Priority), Qwen2.5-7B, Qwen2.5-14B, GPT-OSS-120B.

# %%
# 1. Setup
# !git clone https://github.com/technoob05/Trembling-Triads.git
# %cd Trembling-Triads

# --- ROBUST INSTALL FOR GPT-OSS-120B / UNSLOTH ---
# !pip install --upgrade -qqq uv
# !uv pip install --system -qqq "unsloth[base] @ git+https://github.com/unslothai/unsloth" "unsloth_zoo" "transformers==4.56.2" bitsandbytes accelerate pandas openai anthropic mistralai python-dotenv

# %% [markdown]
# ### 🟢 Phase 1: Baseline (0% Noise)
# Establish the "Ideal Interaction" pattern across scales.

# %%
# --- ⚡ PRIORITY RUN: MEDIUM MODEL (32B) ---
# Fastest for verification while maintaining high capability.
# !python triad_experiment.py --game PD --models "Qwen2.5-32B" --noise 0.0 --rounds 100 --languages en,vn

# %%
# --- Super Large Models (Slow, use only if A100 is available) ---
# !python triad_experiment.py --game PD --models "/kaggle/input/gpt-oss-120b/transformers/default/1" --noise 0.0 --rounds 100 --languages en,vn

# --- Small Models ---
# !python triad_experiment.py --game PD --models Qwen2.5-14B --noise 0.0 --rounds 100 --languages en,vn
# !python triad_experiment.py --game PD --models Qwen2.5-7B --noise 0.0 --rounds 100 --languages en,vn

# %% [markdown]
# ### ⚠️ Phase 2: The Trembling Hand (5% Noise)
# Introduce light accidents. Does the coalition survive?

# %%
# --- ⚡ PRIORITY RUN: MEDIUM MODEL (32B) ---
# !python triad_experiment.py --game PD --models "Qwen2.5-32B" --noise 0.05 --rounds 100 --languages en,vn

# %% [markdown]
# ### 🔴 Phase 3: Chaos (10% Noise)
# High uncertainty. Only the most sophisticated agents should maintain cooperation here.

# %%
# --- ⚡ PRIORITY RUN: MEDIUM MODEL (32B) ---
# !python triad_experiment.py --game PD --models "Qwen2.5-32B" --noise 0.1 --rounds 100 --languages en,vn
