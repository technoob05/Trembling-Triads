# %% [markdown]
# # 🧪 Exp A: The Scale Test (Pillar 1: 3-IPD)
#
# ## 🎯 Objective (Research Pillar 1)
# Investigate **"Trembling Hand Perfection"** using the **3-Player Prisoner's Dilemma (3-IPD)** across a wide spectrum of model sizes.
# We test the **Coalition Stability Score (CSS)**: If we inject noise into a stable coalition, does it collapse?
#
# **Hypothesis:**
# *   **Small Models (7B)**: Fragile. One accidental defection triggers endless retaliation (DDD).
# *   **Medium Models (14B/32B)**: Transitional region. May show emerging forgiveness.
# *   **Large Models (70B)**: Robust. Can forgive accidental errors to restore the coalition.
#
# **Protocol:**
# *   **Game:** 3-Player Adjusted PD (Strict Payoff: 7/1/9/5).
# *   **Noise Levels:** $\epsilon \in \{0\%, 5\%, 10\%\}$.
# *   **Models:** Qwen2.5 Series (7B, 14B, 32B, 72B) or Llama3 (8B, 70B).

# %%
# 1. Setup
# !git clone https://github.com/technoob05/Trembling-Triads.git
# %cd Trembling-Triads
# !pip install -r requirements.txt

# %% [markdown]
# ### 🟢 Phase 1: Baseline (0% Noise)
# Establish the "Ideal Interaction" pattern across scales.

# %%
# Small (7B/8B)
# !python triad_experiment.py --game PD --models Qwen2.5-7B --noise 0.0 --rounds 20
# !python triad_experiment.py --game PD --models Llama3-8B --noise 0.0 --rounds 20

# %%
# Medium (14B / 32B) - Crucial for "Efficiency Paradox"
# !python triad_experiment.py --game PD --models Qwen2.5-14B --noise 0.0 --rounds 20
# !python triad_experiment.py --game PD --models Qwen2.5-32B --noise 0.0 --rounds 20
# !python triad_experiment.py --game PD --models Gemma2-27B --noise 0.0 --rounds 20

# %%
# Large (70B+) - H100 Required
# !python triad_experiment.py --game PD --models Qwen2.5-72B --noise 0.0 --rounds 20
# !python triad_experiment.py --game PD --models Llama3-70B --noise 0.0 --rounds 20

# %% [markdown]
# ### ⚠️ Phase 2: The Trembling Hand (5% Noise)
# Introduce light accidents. Does the coalition survive?
# Run this for ALL sizes to check the robustness curve.

# %%
# Run all sizes with Noise 0.05
# !python triad_experiment.py --game PD --models Qwen2.5-7B,Qwen2.5-14B,Qwen2.5-32B --noise 0.05 --rounds 20

# %% [markdown]
# ### 🔴 Phase 3: Chaos (10% Noise)
# High uncertainty. Only the most sophisticated agents should maintain cooperation here.

# %%
# Run all sizes with Noise 0.1
# !python triad_experiment.py --game PD --models Qwen2.5-7B,Qwen2.5-14B,Qwen2.5-32B --noise 0.1 --rounds 20

# Large Models via H100
# !python triad_experiment.py --game PD --models Qwen2.5-72B,Llama3-70B --noise 0.1 --rounds 20
